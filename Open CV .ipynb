# %%
pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Obtaining dependency information for opencv-contrib-python from https://files.pythonhosted.org/packages/a7/9e/7110d2c5d543ab03b9581dbb1f8e2429863e44e0c9b4960b766f230c1279/opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\anaconda3\lib\site-packages (from opencv-contrib-python) (1.24.3)
# Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
# Installing collected packages: opencv-contrib-python
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\admin\\anaconda3\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import face_recognition
import cv2

# Personal details dictionary associated with recognized faces
personal_details = {
    "Naveen Kumar": {
        "Name": "Naveen Kumar",
        "Email": "naveen@example.com",
        "Phone": "123-456-7890",
        "Occupation": "Data Scientist"
    }
}

# Load the known image (naveen.jpg) and encode it
known_image = face_recognition.load_image_file(r"naveen.jpg.jpg")
known_face_encoding = face_recognition.face_encodings(known_image)[0]

# Provide the path to the image feed (unknown image)
unknown_image_path = r"naveen.jpg.jpg"

# Load the unknown image and encode it
unknown_image = face_recognition.load_image_file(unknown_image_path)
unknown_face_encodings = face_recognition.face_encodings(unknown_image)

if len(unknown_face_encodings) > 0:
    # Compare each face in the unknown image with the known face encoding
    for unknown_face_encoding in unknown_face_encodings:
        matches = face_recognition.compare_faces([known_face_encoding], unknown_face_encoding)

        if matches[0]:
            # If a match is found, output personal details
            name = "Naveen Kumar"
            details = personal_details.get(name)
            print(f"Recognized: {details}")
        else:
            print("No match found")
else:
    print("No faces found in the image.")
# Out:
# Recognized: {'Name': 'Naveen Kumar', 'Email': 'naveen@example.com', 'Phone': '123-456-7890', 'Occupation': 'Data Scientist'}

# %%
pip install winsound
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement winsound (from versions: none)
# ERROR: No matching distribution found for winsound

# %%
pip install playsound
# Out:
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py): started
#   Building wheel for playsound (setup.py): finished with status 'done'
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7046 sha256=48b4c5d1df2dea1f6ebe2cc2b4f194d8d4d232f2a99aa059cc86f86c44a6bd81
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\50\98\42\62753a9e1fb97579a0ce2f84f7db4c21c09d03bb2091e6cef4
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygame
# Out:
# Collecting pygame
#   Obtaining dependency information for pygame from https://files.pythonhosted.org/packages/1b/e0/edce124be8f73249e6b862e13107adc1f7e3b275ed9468d018026b6fbf91/pygame-2.6.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pygame-2.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.0-cp311-cp311-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB 495.5 kB/s eta 0:00:22
#     --------------------------------------- 0.2/10.8 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/10.8 MB 2.3 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/10.8 MB 3.0 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/10.8 MB 3.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.1/10.8 MB 3.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/10.8 MB 3.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/10.8 MB 3.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/10.8 MB 3.9 MB/s eta 0:00:03
#    ------- -------------------------------- 2.0/10.8 MB 4.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.3/10.8 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/10.8 MB 4.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/10.8 MB 4.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/10.8 MB 3.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.7/10.8 MB 3.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.8/10.8 MB 3.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.0/10.8 MB 3.6 MB/s eta 0:00:03
#    ------------ --------------------------- 3.3/10.8 MB 3.8 MB/s eta 0:00:02
#    ------------- -------------------------- 3.6/10.8 MB 3.8 MB/s eta 0:00:02
#    -------------- ------------------------- 3.8/10.8 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 4.0/10.8 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 4.3/10.8 MB 4.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/10.8 MB 4.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/10.8 MB 4.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.9/10.8 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 5.1/10.8 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.2/10.8 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.4/10.8 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 5.6/10.8 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/10.8 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.0/10.8 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.2/10.8 MB 3.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.4/10.8 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 6.6/10.8 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 6.7/10.8 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 7.0/10.8 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.2/10.8 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.8 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.5/10.8 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.7/10.8 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.8 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.8 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.3/10.8 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.4/10.8 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.6/10.8 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.6/10.8 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.8 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.8 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.1/10.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.3/10.8 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.6/10.8 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 9.8/10.8 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.1/10.8 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.8 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/10.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 3.9 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install prettytable
# Out:
# Collecting prettytable
#   Obtaining dependency information for prettytable from https://files.pythonhosted.org/packages/d9/5a/bfdc26c0e19156992b1dc9de47f0b2e8992fe43db9981d814f860bdce2b3/prettytable-3.11.0-py3-none-any.whl.metadata
#   Downloading prettytable-3.11.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: wcwidth in c:\users\admin\anaconda3\lib\site-packages (from prettytable) (0.2.5)
# Downloading prettytable-3.11.0-py3-none-any.whl (28 kB)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import face_recognition
import cv2
import pygame  # For playing sound from a file
from prettytable import PrettyTable  # For displaying details in table format

# Initialize pygame mixer
pygame.mixer.init()

# Dictionary to store personal details for each recognized person
personal_details = {
    "Naveen Kumar": {
        "Name": "Naveen Kumar",
        "Email": "naveen@gmail.com",
        "Phone": "123-456-7897",
        "Occupation": "Data Scientist",
        "Blood Group": "O+ve",
        "Address": "Gandhipuram" 
    },
    "Jana": {
        "Name": "Jana",
        "Email": "jana@gmail.com",
        "Phone": "777-987-6543",
        "Occupation": "Software developer",
        "Blood Group": "B+ve",
        "Address": "Palladam"
    },
    "Susin": {
        "Name": "Susin",
        "Email": "susin@gmail.com",
        "Phone": "666-456-7890",
        "Occupation": "Analyst",
        "Blood Group": "AB+ve",
        "Address": "Ukkadam"
    },
    "Latha": {
        "Name": "Latha",
        "Email": "latha@gmail.com",
        "Phone": "555-123-4567",
        "Occupation": "Teacher",
        "Blood Group": "A+ve",
        "Address": "Race Course"
    },
    "Harish": {
        "Name": "Harish",
        "Email": "harish@gmail.com",
        "Phone": "888-999-1234",
        "Occupation": "Engineer",
        "Blood Group": "O-ve",
        "Address": "Singanallur"
    },
    "Pandi": {
        "Name": "Pandi",
        "Email": "pandi@gmail.com",
        "Phone": "999-777-5555",
        "Occupation": "Technician",
        "Blood Group": "B+ve",
        "Address": "Sulur"
    },
    "Sabarish": {
        "Name": "Sabarish",
        "Email": "sabarish@gmail.com",
        "Phone": "777-555-1234",
        "Occupation": "Consultant",
        "Blood Group": "A-ve",
        "Address": "Peelamedu"
    }
}


# List to store face encodings and names
known_face_encodings = []
known_face_names = []

# Function to load an image, get the encoding, and add to the list
def load_known_face(image_path, name):
    image = face_recognition.load_image_file(image_path)
    encoding = face_recognition.face_encodings(image)[0]
    known_face_encodings.append(encoding)
    known_face_names.append(name)

# Load the known images of the 4 members
load_known_face(r"naveen.jpg.jpg", "Naveen Kumar")
load_known_face(r"Jana.jpeg", "Jana")
load_known_face(r"Susin.jpeg", "Susin")
load_known_face(r"Latha.jpeg", "Latha")
load_known_face(r"harish.jpeg", "Harish")
load_known_face(r"pandi.jpeg", "Pandi")
load_known_face(r"sabarish.jpeg", "Sabarish")

# Path to the beep sound file (make sure this path points to your sound file)
beep_sound_path = r"bombsound.wav"  # Update with actual path to your .wav file

# Create a PrettyTable instance
table = PrettyTable()
table.field_names = ["Name", "Email", "Phone", "Occupation", "Blood Group", "Address"]  # Ensure consistency here

# Initialize the webcam
video_capture = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()

    if not ret:
        print("Failed to grab frame")
        break

    # Convert the image from BGR (OpenCV) to RGB (face_recognition)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Find all face locations and encodings in the current frame
    face_locations = face_recognition.face_locations(rgb_frame)
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    # Process each face found in the frame
    for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        # Compare the detected face with all known faces
        results = face_recognition.compare_faces(known_face_encodings, face_encoding)

        if True in results:
            match_index = results.index(True)
            name = known_face_names[match_index]
            details = personal_details.get(name)
            
            if details:
                # Play the beep sound when a match is found
                pygame.mixer.music.load(beep_sound_path)
                pygame.mixer.music.play()
                
                # Wait until the sound has finished playing
                while pygame.mixer.music.get_busy():
                    pygame.time.Clock().tick(10)
                
                # Display the details on the screen
                table.clear_rows()  # Clear previous results
                table.add_row([details["Name"], details["Email"], details["Phone"], details["Occupation"], details["Blood Group"], details["Address"]])
                
                # Print the table with details
                print("Recognized:")
                print(table)
                
                # Optionally, you could also show the details on the frame
                cv2.putText(frame, f"Recognized: {name}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
                cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
            else:
                print("No details found for the recognized person.")
        else:
            print("No match found")

    # Display the resulting frame
    cv2.imshow('Video', frame)

    # Break the loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close windows
video_capture.release()
cv2.destroyAllWindows()
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# No match found
# Recognized:
# +--------------+------------------+--------------+----------------+-------------+-------------+
# |     Name     |      Email       |    Phone     |   Occupation   | Blood Group |   Address   |
# +--------------+------------------+--------------+----------------+-------------+-------------+
# | Naveen Kumar | naveen@gmail.com | 123-456-7897 | Data Scientist |     O+ve    | Gandhipuram |
# +--------------+------------------+--------------+----------------+-------------+-------------+
# Recognized:
# +------+----------------+--------------+--------------------+-------------+----------+
# | Name |     Email      |    Phone     |     Occupation     | Blood Group | Address  |
# +------+----------------+--------------+--------------------+-------------+----------+
# | Jana | jana@gmail.com | 777-987-6543 | Software developer |     B+ve    | Palladam |
# +------+----------------+--------------+--------------------+-------------+----------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+
# No match found
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Susin | susin@gmail.com | 666-456-7890 |  Analyst   |    AB+ve    | Ukkadam |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +-------+-----------------+--------------+------------+-------------+---------+
# |  Name |      Email      |    Phone     | Occupation | Blood Group | Address |
# +-------+-----------------+--------------+------------+-------------+---------+
# | Pandi | pandi@gmail.com | 999-777-5555 | Technician |     B+ve    |  Sulur  |
# +-------+-----------------+--------------+------------+-------------+---------+
# Recognized:
# +--------+------------------+--------------+------------+-------------+-------------+
# |  Name  |      Email       |    Phone     | Occupation | Blood Group |   Address   |
# +--------+------------------+--------------+------------+-------------+-------------+
# | Harish | harish@gmail.com | 888-999-1234 |  Engineer  |     O-ve    | Singanallur |
# +--------+------------------+--------------+------------+-------------+-------------+

# %% [markdown]
# # Hospital Data Extraction

# %%
# Create a list of dictionaries containing hospital data
hospitals_data = [
    {
        "hospital_name": "Kauvery Hospital",
        "address": "Trichy Road, Trichy",
        "blood_group": "O Positive",
        "availability": 75
    },
    {
        "hospital_name": "Apollo Hospital",
        "address": "Chathiram Bus Stand, Trichy",
        "blood_group": "A Positive",
        "availability": 60
    },
    {
        "hospital_name": "Maruthi Hospital",
        "address": "Srirangam, Trichy",
        "blood_group": "O Negative",
        "availability": 35
    },
    {
        "hospital_name": "Sundaram Hospital",
        "address": "Thillai Nagar, Trichy",
        "blood_group": "B Positive",
        "availability": 71
    },
    {
        "hospital_name": "Gevian Hospital",
        "address": "Cantonment, Trichy",
        "blood_group": "AB Positive",
        "availability": 57
    }
]

def find_hospital(blood_group):
    # Iterate through hospitals_data to find the appropriate blood group
    for hospital in hospitals_data:
        if hospital["blood_group"].lower() == blood_group.lower():
            print(f"Hospital Name: {hospital['hospital_name']}")
            print(f"Address: {hospital['address']}")
            print(f"Blood Group: {hospital['blood_group']}")
            print(f"Availability: {hospital['availability']}%")
            return

    # If no match is found
    print("Sorry, no hospital found with the specified blood group in Trichy.")

# Ask user for blood group input
user_blood_group = input("Enter the blood group you are looking for (e.g., O Positive, A Positive): ")
find_hospital(user_blood_group)
# Out:
# Enter the blood group you are looking for (e.g., O Positive, A Positive): O Positive
# Hospital Name: Kauvery Hospital
# Address: Trichy Road, Trichy
# Blood Group: O Positive
# Availability: 75%
